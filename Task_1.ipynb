# %%
import re
def login():
    login_u=input("Enter the Username ")
    pass_u=input("Enter the Password ")
    fin = open("c:\\users\\204247\\Desktop\\Task.txt")
    for i in fin: 
        word = i.strip()
        if word==login_u:
            a=word
        else:
            a=word
        if word==pass_u:
            b=word
        else:
            b=word
    if a==login_u and b==pass_u:
        print("Happy Login!!")
    else:
        print("Try forgot password")
        x=str(input("To contine type 'y' "))
        if x == "y":
            if login_u in open("c:\\users\\204247\\Desktop\\Task.txt"):
                print(open("c:\\users\\204247\\Desktop\\Task.txt").read())
            else:
                print("Please Register")
                reg()

def reg():
    name=input("Enter your username : ")
    password=input("Enter your password : ")
    password1=input("Re-Enter your password : ")
    def user(name):
        pat = "^[a-zA-Z0-9-_]+@[a-zA-Z0-9]+\.[a-z]{1,3}$"
        if re.match(pat,name):
            return True
        return False
    if user(name)==False:
        print("Enter valid email address")
        reg()
    a=len(password)
    if password != password1:
        print("The password deosn't match")
    if a>5 and a<17:
        if password==password1:
            upper = any(i.isupper() for i in password)
            if upper!=True:
                print("Password must contain one uppercase")
                reg()
            lower = any(i.islower() for i in password)
            if lower!=True:
                print("Password must contain one lowercase")
                reg()
            num = any(i.isdigit() for i in password)
            if num!=True:
                print("Password must contain a number")
                reg()   
    else:
        print("Password criteria doesn't match \nTry again")
        reg()
    file = open("c:\\users\\204247\\Desktop\\Task.txt",'w')
    file.write(name)
    file.write("\n"+password)
    file.close()
    login()   
    
                    
reg()
